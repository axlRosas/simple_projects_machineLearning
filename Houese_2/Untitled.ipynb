# %% [markdown]
# # Part 1: Data Preproseccing

# %% [markdown]
# dataset link: https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
dataset=pd.read_csv('train.csv')

# %%
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
dataset.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %% [markdown]
# ## Dealing null values

# %%
dataset.isnull().values.sum()
# Out:
# 6965

# %%
dataset.columns[dataset.isnull().any()]
# Out:
# Index(['LotFrontage', 'Alley', 'MasVnrType', 'MasVnrArea', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Electrical', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence',
#        'MiscFeature'],
#       dtype='object')

# %%
len(dataset.columns[dataset.isnull().any()])
# Out:
# 19

# %%
#null values with heatmap

plt.figure(figsize=(16,9))
sns.heatmap(dataset.isnull())
# Out:
# <AxesSubplot:>

# %%
null_percent=dataset.isnull().sum()/dataset.shape[0]*100
#missing values/ total values)*100

# %%
null_percent
# Out:
# Id                0.000000
# MSSubClass        0.000000
# MSZoning          0.000000
# LotFrontage      17.739726
# LotArea           0.000000
#                    ...
# MoSold            0.000000
# YrSold            0.000000
# SaleType          0.000000
# SaleCondition     0.000000
# SalePrice         0.000000
# Length: 81, dtype: float64

# %%
cols_drop=null_percent[null_percent>50].keys()
cols_drop
# Out:
# Index(['Alley', 'PoolQC', 'Fence', 'MiscFeature'], dtype='object')

# %%
dataset=dataset.drop(columns=['Alley', 'PoolQC', 'Fence', 'MiscFeature'])

# %%
#Add column mean to numerical columns
dataset['LotFrontage']=dataset['LotFrontage'].fillna(dataset['LotFrontage'].mean())
dataset['MasVnrArea']=dataset['MasVnrArea'].fillna(dataset['MasVnrArea'].mean())
dataset['GarageYrBlt']=dataset['GarageYrBlt'].fillna(dataset['GarageYrBlt'].mean())

# %%
len(dataset.columns[dataset.isnull().any()])
# Out:
# 12

# %% [markdown]
# ### Add columns mode to categorical columns

# %%
dataset.select_dtypes(include='object').columns
# Out:
# Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
cat_mis_cols=dataset.columns[dataset.isnull().any()]
cat_mis_cols
# Out:
# Index(['MasVnrType', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#        'BsmtFinType2', 'Electrical', 'FireplaceQu', 'GarageType',
#        'GarageFinish', 'GarageQual', 'GarageCond'],
#       dtype='object')

# %%
[dataset[col].fillna(dataset[col].mode()[0],inplace=True) for col in cat_mis_cols]
# Out:
# [None, None, None, None, None, None, None, None, None, None, None, None]

# %%
len(dataset.columns[dataset.isnull().any()])
# Out:
# 0

# %% [markdown]
# ## Distplot

# %%
plt.figure(figsize=(16,9))
bar=sns.displot(dataset['SalePrice'])
bar.legend(["skewness: {:.2f}".format(dataset['SalePrice'].skew())])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-f3f657005965> in <module>
#       1 plt.figure(figsize=(16,9))
#       2 bar=sns.displot(dataset['SalePrice'])
# ----> 3 bar.legend(["skewness: {:.2f}".format(dataset['SalePrice'].skew())])
#
# TypeError: 'NoneType' object is not callable

# %%
X=dataset.drop(columns='SalePrice')

# %%
X.corrwith(dataset['SalePrice']).plot.bar(
    figsize=(16,9),title='Corr with sale price',grid=True
)
# Out:
# <AxesSubplot:title={'center':'Corr with sale price'}>

# %%
plt.figure(figsize=(25,25))
ax=sns.heatmap(data=dataset.corr(), cmap='coolwarm',annot=True,linewidths=2)

# %%
high_corr=dataset.corr()

# %%
high_corr_features=high_corr.index[abs(high_corr['SalePrice'])> 0.5]

# %%
plt.figure(figsize=(16,9))
ax=sns.heatmap(data=dataset[high_corr_features].corr(), cmap='coolwarm',annot=True,linewidths=2)

# %% [markdown]
# # Dealing with categorical values

# %%
len(dataset.select_dtypes(include='object').columns)
# Out:
# 39

# %%
dataset=pd.get_dummies(data=dataset,drop_first=True)

# %% [markdown]
# ## Splitting the dataset

# %%
y=dataset['SalePrice']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

# %%
X_train.apply(lambda row: row.astype(str).str.contains('RL').any(), axis=1)
# Out:
# 618      True
# 870      True
# 92       True
# 817      True
# 302      True
#         ...
# 763      True
# 835      True
# 1216    False
# 559      True
# 684      True
# Length: 1168, dtype: bool

# %%
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-2266c3d62494> in <module>
#       1 sc=StandardScaler()
# ----> 2 X_train=sc.fit_transform(X_train)
#       3 X_test=sc.transform(X_test)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     697         if y is None:
#     698             # fit method of arity 1 (unsupervised transformation)
# --> 699             return self.fit(X, **fit_params).transform(X)
#     700         else:
#     701             # fit method of arity 2 (supervised transformation)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y, sample_weight)
#     728         # Reset internal state before fitting
#     729         self._reset()
# --> 730         return self.partial_fit(X, y, sample_weight)
#     731
# ...
